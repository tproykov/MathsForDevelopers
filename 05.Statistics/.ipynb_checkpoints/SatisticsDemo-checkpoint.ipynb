# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Statistics

# %% [markdown]
# ## Live demos

# %%
snowfall_data = pd.read_table("data/snowfall.csv", header = None)

# %%
type(snowfall_data)
# Out:
# pandas.core.frame.DataFrame

# %%
snowfall_data.columns = ["snowfall"]

# %%
snowfall_data
# Out:
#     snowfall
# 0      126.4
# 1       82.4
# 2       78.1
# 3       51.1
# 4       90.9
# ..       ...
# 58      66.1
# 59      78.4
# 60     120.5
# 61      97.0
# 62     110.0
#
# [63 rows x 1 columns]

# %%
snowfall_data.mean()
# Out:
# snowfall    80.296825
# dtype: float64

# %%
plt.hist(snowfall_data)
plt.xlabel("Snowfall [inches]")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(snowfall_data, bins = 20)
plt.xlabel("Snowfall [inches]")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(snowfall_data, bins = 5)
plt.xlabel("Snowfall [inches]")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(snowfall_data, bins = 15)
plt.xlabel("Snowfall [inches]")
plt.ylabel("Frequency")
plt.show()
